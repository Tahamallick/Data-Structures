# %% [markdown]
# # Task 1 & 2

# %%
class Node:
    def __init__ (self, value):
        self.value = value;
        self.next = None;

class LinkedList:
    def __init__(self, *values):
        if len(values) != 0:
            self.head = values[0];
            for i in range(1, values):
                self.add(values[i])
        else:
            self.head = None
        
    def add(self, value):
        newnode = Node(value);
        currentnode = self.head;
        if currentnode is not None:
            while(currentnode.next is not None):
                currentnode = currentnode.next;
            currentnode.next = newnode;
        else:
            self.head = newnode;
            
    def remove(self, value):
        currentnode = self.head;
        if currentnode.value == value:
            self.head = currentnode.next;
            return;
        else:
            while(currentnode is not None):
                prev = currentnode;
                currentnode = currentnode.next;
                if currentnode.value == value:
                    found = True;
                    break;
            if found:
                prev.next = currentnode.next;
            
    def search(self, value):
        currentnode = self.head;
        if currentnode is not None:
            while (currentnode.next != None and currentnode.value != value):
                currentnode = currentnode.next;
            if currentnode.value == value:
                return True;
        return False;
    
    def prepend(self, value):
        newnode = Node(value);
        newnode.next = self.head;
        self.head = newnode;
        
    def __len__(self):
        currentnode = self.head;
        count = 0;
        if currentnode is not None:
            count += 1;
            while (currentnode.next is not None):
                currentnode = currentnode.next;
                count += 1;
            return count;
        else:
            return count;
        
    def __str__ (self):
        string = ""
        currentnode = self.head
        string += str(currentnode.value) + " "; 
        while (currentnode.next is not None):
            currentnode = currentnode.next
            string += str(currentnode.value) + " ";
        return string
        
    def removeAll(self):
        prev = self.head;
        currentnode = head.next;
        while (currentnode.next is not None):
            prev.next = None;
            prev = currentnode;
            currentnode = currentnode.next;
            
    
    def splitInHalf(self):
        length = len(self);
        if length != 1:
            firstnode = self.head;
            currentnode = firstnode;
            count = 1;
            while(count != length//2):
                currentnode = currentnode.next;
                count += 1;
            firstnode.next = currentnode;
            
    def __iter__(self):
        return LinkedListIterator(self.head)
    
    def sort(self):
        n = len(self);
        currentnode = self.head;
        prevnode = currentnode;
        end = n;
        index = 0;
        while (index < n):
            index += 1;
            highest = self.head;
            currentnode = highest.next;
            prevnode = highest;
            #end -= 1
            i = 0
            while(index < end and highest.value > currentnode.value):
                if i == 0:
                    self.head = currentnode;
                    prevnode = currentnode;
                    currentnode = currentnode.next
                    i += 1;
                else:
                    prevnode.next = currentnode;
                    prevnode = prevnode.next;
                    currentnode = currentnode.next;
                    #current += 1;
                if currentnode is None:
                    break;
            prevnode.next = highest;
            highest.next = currentnode;
            
class LinkedListIterator:
    def __init__(self, head):
        self.head = head;
        self.current = self.head;
        self.prev = self.current;
        
    def __iter__ (self):
        return self;
    
    def __next__(self):
        while (self.prev.next != None):
            self.prev = self.current;
            self.current = self.current.next;
            return self.prev.value;
        else:
            raise StopIteration;
            
l1 = LinkedList();
l1.add(1);
l1.add(2);
l1.add(4);
l1.add(5435);
print(l1);
print("search found: ", l1.search(23));
l1.remove(1);
l1.remove(2);
print(l1);
l1.prepend(91837);
#l1.removeAll(e1);
print(l1)
l1.add(64567);
l1.add(123);
l1.add(32);
l1.add(64);
l1.add(974);
l1.add(23)
print(l1)
print(len(l1))
#l1.splitInHalf();
#print(l1)
#for i in l1:
#    print(i)
l1.sort()
print(l1)
# Out:
# 1 2 4 5435
# search found:  False
# 4 5435
# 91837 4 5435
# 91837 4 5435 64567 123 32 64 974 23
# 9
# 4 5435 64567 123 32 64 974 23 91837

# %% [markdown]
# # Task 3

# %%
class Set:
    def __init__(self, *element):
        self.elements = LinkedList();
        for j in element:
            self.add(j);
        
        
    def __len__(self):
        return len(self.elements)
    
    def contains(self, value):
        if self.elements.search(value):
            return True
        return False
    
    def add(self, value):
        if self.contains(value):
            return;
        else:
            self.elements.add(value)
    
    def remove(self, value):
        assert self.contains(value)
        self.elements.remove(value)
    
    def eq(self, otherset):
        if len(self) == len(otherset):
            for element in self.elements:
                if element not in otherset.elements:
                    return False
            return True
        return False 
    
    def issubsetof(self, otherset):
        for element in self.elements:
            if element not in otherset.elements:
                return False
        return True
    
    def union(self, otherset):
        newset = Set()
        for element in self.elements:
            newset.add(element)
        for element in otherset.elements:
            if newset.contains(element) == False:
                newset.add(element)
        return newset
    
    def intersect(self, otherset):
        newset = Set()
        for element in self.elements:
            if otherset.contains(element):
                newset.add(element)
        return newset
                
    def __str__(self):
        s = "{"
        for x in self.elements:
            s += str(x) + ","
        s += "}"
        return (s)
    
    def difference(self, otherset):
        newset = Set()
        for elements in self.elements:
            if otherset.contains(elements) == False:
                newset.add(elements)
        return newset
    
    def __iter__(self):
        return Iterator(self.elements)
    
    def propersubset(self, otherset):
        if len(self) != len(otherset):
            for x in self:
                if otherset.contains(x) == False:
                    return False
        return True
    
class Iterator:
    def __init__(self, sets):
        self.sets = sets;
        self.prev = self.sets.head;
        self.current = self.prev;
        self.index = 0
    
    def __iter__(self):
        return self
    
    def __next__(self):
        while (self.prev.next != None):
            self.prev = self.current;
            self.current = self.current.next;
            return self.prev.value;
        else:
            raise StopIteration;
    
            
        
        
    
sets = Set(5, 2, 1, 10, 3, 2)
sets2 = Set(97, 320, 43, 2)
sets3 = Set(1, 10, 2)
print(sets.contains(10))
print(sets2)
print(sets)
q = sets.intersect(sets2)
print(q)
w = sets.union(sets2)
print(w)
e = sets.union(sets2)
w.eq(e)
for i in w:
    print(i)
pa = Set(1, 2, 4, 5)
print(pa)
sets3.propersubset(sets)
# Out:
# True
# {97,320,43,2,}
# {5,2,1,10,3,}
# {}
# {5,2,1,10,3,97,320,43,}
# 5
# 2
# 1
# 10
# 3
# 97
# 320
# 43
# {1,2,4,5,}
# True

# %%
class Node:
    def __init__(self, value):
        self.value = value;
        self.next = None;
        
class SortedLinkedList:
    def __init__(self, *values):
        self.head = None;
        if len(values) != 0:
            for i in values:
                self.add(i);
        
    def add(self, value):
        newnode = Node(value);
        currentnode = self.head;
        if currentnode is not None:
            if newnode.value < currentnode.value:
                self.prepend(value);
            else:
                while(currentnode.next is not None and (value > currentnode.next.value)):
                    currentnode = currentnode.next;
                newnode.next = currentnode.next;
                currentnode.next = newnode;
        else:
            self.head = newnode;
            
    def prepend(self, value):
        newnode = Node(value);
        newnode.next = self.head;
        self.head = newnode;
        
    def remove(self, value):
        found = False;
        currentnode = self.head;
        if currentnode.value == value:
            self.head = currentnode.next;
            return;
        else:
            while(currentnode.next is not None):
                prev = currentnode;
                currentnode = currentnode.next;
                if currentnode.value == value:
                    found = True;
                    break;
            if found:
                prev.next = currentnode.next;
            return
                
    def search(self, value):
        currentnode = self.head;
        if currentnode is not None:
            while (currentnode.next != None and currentnode.value != value):
                currentnode = currentnode.next;
            if currentnode.value == value:
                return True;
        return False;
    
    def __len__(self):
        currentnode = self.head;
        count = 0;
        if currentnode is not None:
            count += 1;
            while (currentnode.next is not None):
                currentnode = currentnode.next;
                count += 1;
            return count;
        else:
            return count;
        
    def __str__ (self):
        string = ""
        currentnode = self.head
        string += str(currentnode.value) + " "; 
        while (currentnode.next is not None):
            currentnode = currentnode.next
            string += str(currentnode.value) + " ";
        return string
        
    def removeAll(self):
        prev = self.head;
        currentnode = head.next;
        while (currentnode.next is not None):
            prev.next = None;
            prev = currentnode;
            currentnode = currentnode.next;
            
    
    def splitInHalf(self):
        length = len(self);
        if length != 1:
            firstnode = self.head;
            currentnode = firstnode;
            count = 1;
            while(count != length//2):
                currentnode = currentnode.next;
                count += 1;
            firstnode.next = currentnode;
            
    def __iter__(self):
        return LinkedListIterator(self.head)
    
    
class LinkedListIterator:
    def __init__(self, head):
        self.head = head;
        self.current = self.head;
        self.prev = self.current;
        
    def __iter__ (self):
        return self;
    
    def __next__(self):
        while (self.prev.next != None):
            self.prev = self.current;
            self.current = self.current.next;
            return self.prev.value;
        else:
            raise StopIteration;
            

            
class Set:
    def __init__(self, *element):
        self.elements = SortedLinkedList();
        for j in element:
            self.add(j);
        
        
    def __len__(self):
        return len(self.elements)
    
    def contains(self, value):
        if self.elements.search(value):
            return True
        return False
    
    def add(self, value):
        if self.contains(value):
            return;
        else:
            self.elements.add(value)
    
    def remove(self, value):
        assert self.contains(value)
        self.elements.remove(value)
    
    def eq(self, otherset):
        if len(self) == len(otherset):
            for element in self.elements:
                if element not in otherset.elements:
                    return False
            return True
        return False 
    
    def issubsetof(self, otherset):
        for element in self.elements:
            if element not in otherset.elements:
                return False
        return True
    
    def union(self, otherset):
        newset = Set()
        for element in self.elements:
            newset.add(element)
        for element in otherset.elements:
            if newset.contains(element) == False:
                newset.add(element)
        return newset
    
    def intersect(self, otherset):
        newset = Set()
        for element in self.elements:
            if otherset.contains(element):
                newset.add(element)
        return newset
                
    def __str__(self):
        s = "{"
        for x in self.elements:
            s += str(x) + ","
        s += "}"
        return (s)
    
    def difference(self, otherset):
        newset = Set()
        for elements in self.elements:
            if otherset.contains(elements) == False:
                newset.add(elements)
        return newset
    
    def __iter__(self):
        return Iterator(self.elements)
    
    def propersubset(self, otherset):
        if len(self) != len(otherset):
            for x in self:
                if otherset.contains(x) == False:
                    return False
        return True
    
class Iterator:
    def __init__(self, sets):
        self.sets = sets;
        self.prev = self.sets.head;
        self.current = self.prev;
        self.index = 0
    
    def __iter__(self):
        return self
    
    def __next__(self):
        while (self.prev.next != None):
            self.prev = self.current;
            self.current = self.current.next;
            return self.prev.value;
        else:
            raise StopIteration;

LinkedList = SortedLinkedList(1, 4, 6, 2, 8, 124, 21, 4, 68, 312, 3235)
print(LinkedList)
LinkedList.remove(5)
LinkedList.add(125)
print(LinkedList)
print(LinkedList)
Set = Set(24, 21, 43, 1, 3, 5, 7, 1, 2)
print(Set)
# Out:
# 1 2 4 4 6 8 21 68 124 312 3235
# 1 2 4 4 6 8 21 68 124 125 312 3235
# 1 2 4 4 6 8 21 68 124 125 312 3235
# {1,2,3,5,7,21,24,43,}

# %% [markdown]
# # Task 4 & 5

# %%
def add1(n):
    total = 0;
    total += contains1(n);
    for i in range(n):
        total += 1;
    return total;

def contains1(n):
    total = 0;
    i = n // 2;
    for i in range(n):
        total += 1;
    return total;

def remove1(n):
    total = 0;
    total += contains1(n);
    for i in range(n):
        total += 1;
    return total;

def search1(n):
    total = 0;
    for i in range(n):
        total += 1;
    return total;


def eq1(n):
    total = 0;
    for i in range(n):
        total += search1(n);
    return total;

def subset1(n):
    total = 0;
    for i in range(n):
        total += search1(n);
    return total;

def union1(n):
    total = 0;
    for i in range(n):
        total += 1;
    for i in range(n):
        total += search1(n);
        total += add1(n)
    return total;

def intersect1(n):
    total = 0;
    for i in range(n):
        total += search1(n);
        total += add1(n)
    return total;

def difference1(n):
    total = 0;
    for i in range(n):
        total += search1(n);
        total += add1(n)
    return total;

def propersubset1(n):
    total = 0;
    for i in range(n):
        total += search1(n);
    return total;

            
def add2(n):
    total = 0;
    total += contains2(n);
    for i in range(n):
        total += 1;
    return total;

def contains2(n):
    total = 0;
    i = n//2;
    while (i > 1):
        total += 1;
        i = i // 2;
    return total;

def remove2(n):
    total = 0;
    total += contains2(n);
    for i in range(n):
        total += 1;
    return total;

def search2(n):
    total = 0;
    i = n //2;
    while(i > 1):
        i= i//2
        total +=1;
    return total;

def eq2(n):
    total = 0;
    for i in range(n):
        total += search2(n);
    return total;

def subset2(n):
    total = 0;
    for i in range(n):
        total += search2(n);
    return total;

def union2(n):
    total = 0;
    for i in range(n):
        total += add2(n);
    for i in range(n):
        total += contains2(n);
        total += add2(n);
    return total;

def intersect2(n):
    total = 0;
    for i in range(n):
        total += contains2(n);
        total += add2(n);
    return total;

def difference2(n):
    total = 0;
    for i in range(n):
        total += contains2(n);
        total += add2(n);
    return total;

def propersubset2(n):
    total = 0;
    for i in range(n):
        total += contains2(n);
    return total;



print("old implementation for add: ", add1(2000), "\t\t\t\t New implementation for add", add2(2000))
print("old implementation for remove: ", remove1(2000), "\t\t\t\t New implementation for remove", remove2(2000))
print("old implementation for contains: ", contains1(2000), "\t\t\t\t New implementation for contains", contains2(2000))
print("old implementation for eq: ", eq1(2000), "\t\t\t\t New implementation for eq", eq2(2000))
print("old implementation for subset: ", subset1(2000), "\t\t\t New implementation for subset", subset2(2000))
print("old implementation for propersubset: ", propersubset1(2000), "\t\t\t New implementation for propersubset", propersubset2(2000))
print("old implementation for difference: ", difference1(2000), "\t\t\t New implementation for difference", difference2(2000))
print("old implementation for intersect: ", intersect1(2000), "\t\t\t New implementation for intersect", intersect2(2000))
print("old implementation for union: ", union1(2000), "\t\t\t New implementation for union", union2(2000))
# Out:
# old implementation for add:  4000 				 New implementation for add 2009
# old implementation for remove:  4000 				 New implementation for remove 2009
# old implementation for contains:  2000 				 New implementation for contains 9
# old implementation for eq:  4000000 				 New implementation for eq 18000
# old implementation for subset:  4000000 			 New implementation for subset 18000
# old implementation for propersubset:  4000000 			 New implementation for propersubset 18000
# old implementation for difference:  12000000 			 New implementation for difference 4036000
# old implementation for intersect:  12000000 			 New implementation for intersect 4036000
# old implementation for union:  12002000 			 New implementation for union 8054000
